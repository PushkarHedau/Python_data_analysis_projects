# %% [markdown]
# # Levels for Data Exploration
#
# * Level 0 : Understanding Data
# * Level 1 : Univariate Analysis

# %% [markdown]
# ## Level 0 Tasks: Understanding Data
#
# 1.Visually inspect the first few and last few rows of the data.
# 2.Check the shape of the data frame.
# 3.Check the count of null values in each column.
# 4.Inspect all the column names and cross check with the data dictionary.
# 5.Check the information of the data frame using the info() function.

# %%
import pandas as pd  # for data reading
import matplotlib.pyplot as plt # for making maps 
from tabulate import tabulate # to create formatted tables
import matplotlib as mat  # to create visualization charts 
import seaborn as sns# also for visualization
import numpy as np  # for numerical operations

import warnings  # to avoid warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("Automobile.csv")
df
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1            buick skylark 320  15.0          8         350.0       165.0
# 2           plymouth satellite  18.0          8         318.0       150.0
# 3                amc rebel sst  16.0          8         304.0       150.0
# 4                  ford torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 393            ford mustang gl  27.0          4         140.0        86.0
# 394                  vw pickup  44.0          4          97.0        52.0
# 395              dodge rampage  32.0          4         135.0        84.0
# 396                ford ranger  28.0          4         120.0        79.0
# 397                 chevy s-10  31.0          4         119.0        82.0
#
#      weight  acceleration  model_year  origin
# ...

# %% [markdown]
# ## Display the names of all the columns

# %%
df.columns
# Out:
# Index(['name', 'mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin'],
#       dtype='object')

# %% [markdown]
# ## Reading the top 50 rows

# %%
df.head(50)
# Out:
#                             name   mpg  cylinders  displacement  horsepower  \
# 0      chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1              buick skylark 320  15.0          8         350.0       165.0
# 2             plymouth satellite  18.0          8         318.0       150.0
# 3                  amc rebel sst  16.0          8         304.0       150.0
# 4                    ford torino  17.0          8         302.0       140.0
# 5               ford galaxie 500  15.0          8         429.0       198.0
# 6               chevrolet impala  14.0          8         454.0       220.0
# 7              plymouth fury iii  14.0          8         440.0       215.0
# 8               pontiac catalina  14.0          8         455.0       225.0
# 9             amc ambassador dpl  15.0          8         390.0       190.0
# 10           dodge challenger se  15.0          8         383.0       170.0
# ...

# %% [markdown]
# ## Reading the bottom 50 rows

# %%
df.tail(50)
# Out:
#                                   name   mpg  cylinders  displacement  \
# 348                      toyota tercel  37.7          4          89.0
# 349                        mazda glc 4  34.1          4          91.0
# 350                 plymouth horizon 4  34.7          4         105.0
# 351                     ford escort 4w  34.4          4          98.0
# 352                     ford escort 2h  29.9          4          98.0
# 353                   volkswagen jetta  33.0          4         105.0
# 354                        renault 18i  34.5          4         100.0
# 355                      honda prelude  33.7          4         107.0
# 356                     toyota corolla  32.4          4         108.0
# 357                       datsun 200sx  32.9          4         119.0
# 358                          mazda 626  31.6          4         120.0
# 359          peugeot 505s turbo diesel  28.1          4         141.0
# ...

# %% [markdown]
# ##  Number of rows and columns

# %%
df.shape
# Out:
# (398, 9)

# %% [markdown]
# ## Displaying the dataset information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          398 non-null    object
#  1   mpg           398 non-null    float64
#  2   cylinders     398 non-null    int64
#  3   displacement  398 non-null    float64
#  4   horsepower    392 non-null    float64
#  5   weight        398 non-null    int64
#  6   acceleration  398 non-null    float64
#  7   model_year    398 non-null    int64
#  8   origin        398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %% [markdown]
# ## Checking if there are null values in any columns

# %%
df.isnull().sum()
# Out:
# name            0
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %% [markdown]
# LEVEL 1 Analysis
# -------------------------
# Identify if the data type in each column is categorical or numerical?
# 1. Separate out the categorical columns from the numerical types
#
# ### These are the kind of analyses that can be performed on categorical data
# 1. Check if it is Nominal or Ordinal
# 2. Check how many categories are present
# 3. Check the Mode
# 4. Check for Missing values
# 5. Think about how the missing values could be treated
# 6. Think about the kind of graph/chart that can be plotted using this data
#
# Note: We are analyzing only one column at a time (Univariate Analysis).

# %% [markdown]
# ## Separating Categorical and Numerical Variables

# %%
# Seprating out the categorical and continuous variables
def seprate_data_types(df):
    categorical = []
    continuous = []
    for column in df.columns:                # looping on the number of columns
        if df[column].dtype== object:     
                                                   
            categorical.append(column)
        else:
            continuous.append(column)
            
    return categorical, continuous 


categorical, continuous = seprate_data_types(df)         # Calling the function


table = [categorical, continuous]
print(tabulate({"Categorical":categorical,
                "continuous": continuous}, headers = ["categorical", "continuous"]))
# Out:
# categorical    continuous
# -------------  ------------
# name           mpg
# origin         cylinders
#                displacement
#                horsepower
#                weight
#                acceleration
#                model_year

# %% [markdown]
# ## correlation matrix

# %%
fig, ax=plt.subplots(figsize=(10,7))
sns.heatmap(df.corr(), annot=True, cbar=0.5, linewidth=0.5, cmap="coolwarm")
plt.show()

# %% [markdown]
# # Connecting to MySQL server

# %% [markdown]
# ## Installing MySQL connector

# %% [markdown]
# ## Import the MySQL connector

# %%
import mysql.connector as sql

# %% [markdown]
# #sql.connector() # is an API which connect the python with MySQL server
#
# #We have to provide the arguement(host,user, password, database name) to connect with the databases created in Mysql server.

# %%
# Ensure you have created a database by name "Automobile_database" by logging into the MySQL instance 
db = sql.connect(host='localhost', user='root',password='Pushkar.1211',database='Automobile_database')
db

# %% [markdown]
# ## cursor() method

# %%
mycursor = db.cursor() # It will create an object of the MySQL cursor class

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# Credentials to database connection
hostname="localhost"
dbname="Automobile_database" # Name of the database into which we want into insert the data 
uname="root"
pwd="Pushkar.1211"


# Create SQLAlchemy engine to connect to MySQL Database

engine = create_engine("mysql+pymysql://{user}:{pw}@{host}/{db}"
.format(host=hostname, db=dbname, user=uname, pw=pwd))

# %%
# Convert dataframe to sql table  

df.to_sql('car_data', engine, index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10792\4000829157.py in <module>
#       1 # Convert dataframe to sql table
#       2
# ----> 3 df.to_sql('car_data', engine, index=False)
#
# F:\python\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2949         from pandas.io import sql
#    2950
# -> 2951         return sql.to_sql(
#    2952             self,
#    2953             name,
#
# F:\python\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     696         )
#     697
# --> 698     return pandas_sql.to_sql(
#     699         frame,
#     700         name,
#
# ...

# %% [markdown]
# # $$\;\;\;\; Univariate \ Analysis \ of \ Categorical \ Variables$$

# %%
df.columns
# Out:
# Index(['name', 'mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin'],
#       dtype='object')

# %%
sns.set_palette("pastel")

# %% [markdown]
# ## Level 1 Analysis (Univariate Analysis)

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("Count of origin")                  # Set the title of the graph
percentage = df["origin"].value_counts()         # value_counts: returns the count of values in series: return series
labels = list(df["origin"].value_counts().index) # Converting the index of value counts into list

sns.countplot(x = df["origin"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  # autopct: to print the percentage on pie wedge. 2 decimal points used 

plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize= (15, 7))               # Creating the space for the 2 images, first argument in subplots is rows and second is columns and the figure size
sns.histplot(x = df["mpg"], ax =ax[1]) # ax[1] means image will plot at the second space
sns.boxplot(x = df["mpg"], ax = ax[0]) # ax[0] means image will plot at the second space
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def bar_count(ax, data):
    """
    Given a matplotlib axis object and a dataset, add count values as text labels to each bar in a bar chart.
    """
    # Get the total count of values in the dataset
    count = len(data)
    
    # Add the count values as text labels
    for bar in ax.patches:
        height = bar.get_height()
        ax.annotate(f"{height}",
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),
                    textcoords="offset points",
                    ha='center',
                    va='bottom')

    # Show the plot
    plt.show()

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = df["cylinders"]) 
bar_count(ax,df)
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize= (15, 7))               # Creating the space for the 2 images, first argument in subplots is rows and second is columns and the figure size
sns.histplot(x = df["displacement"], ax =ax[1]) # ax[1] means image will plot at the second space
sns.boxplot(x = df["displacement"], ax = ax[0]) # ax[0] means image will plot at the second space
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize= (15, 7))               # Creating the space for the 2 images, first argument in subplots is rows and second is columns and the figure size
sns.histplot(x = df["horsepower"], ax =ax[1]) # ax[1] means image will plot at the second space
sns.boxplot(x = df["horsepower"], ax = ax[0]) # ax[0] means image will plot at the second space
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize= (15, 7))               # Creating the space for the 2 images, first argument in subplots is rows and second is columns and the figure size
sns.histplot(x = df["weight"], ax =ax[1]) # ax[1] means image will plot at the second space
sns.boxplot(x = df["weight"], ax = ax[0]) # ax[0] means image will plot at the second space
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize= (15, 7))               # Creating the space for the 2 images, first argument in subplots is rows and second is columns and the figure size
sns.histplot(x = df["acceleration"], ax =ax[1]) # ax[1] means image will plot at the second space
sns.boxplot(x = df["acceleration"], ax = ax[0]) # ax[0] means image will plot at the second space
plt.show()

# %%
sns.set_palette("bright")

# %%
fig, ax = plt.subplots(1,2,figsize= (18, 7))

sns.regplot(x = "mpg", y = "acceleration",  data=df, ax=ax[0])
sns.regplot(x = "displacement", y = "horsepower" , data=df, ax=ax[1])
plt.show()

# %%
fig, ax = plt.subplots(1,2,figsize= (18, 7))

sns.regplot(x = "horsepower", y = "weight",  data=df, ax=ax[0])
sns.regplot(x = "horsepower", y = "acceleration" , data=df, ax=ax[1])
plt.show()

# %%
fig, ax = plt.subplots(1,2,figsize= (18, 7))
sns.barplot(y="acceleration",x ="origin", data=df ,ax=ax[0] )
sns.barplot(y="mpg",x ="origin", data=df ,ax=ax[1] )
plt.show()

# %%
median_acceleration = df.groupby('cylinders')[['acceleration', "horsepower", "mpg", "displacement", "weight"]].median()
median_acceleration
# Out:
#            acceleration  horsepower    mpg  displacement  weight
# cylinders
# 3                  13.5        98.5  20.25          70.0  2375.0
# 4                  16.2        78.0  28.25         105.0  2232.0
# 5                  19.9        77.0  25.40         131.0  2950.0
# 6                  16.1       100.0  19.00         228.0  3201.5
# 8                  13.0       150.0  14.00         350.0  4140.0

# %% [markdown]
# Conclusion--
# ​
#
# There were 9 parameters in the automobile dataset and I have taken all of them in consideration . ​
#
# ​
#
# There were 3 region where the cars were produced ie. USA, EUROPE, JAPAN .​
#
# Majority of cars were produced in USA and least produed in japan. ​
#
# ​
#
# Cars that were produced in USA were high in terms of weight, number of cylinders, displacement and horsepower . The cars produced in usa are powerful can have high speed but are very low fuel efficient  and there acceleration is also less.​
#
# ​
#
# Cars produced from japan and europe are more fuel efficient , they have a better mileage and acceleration and are low in terms of weight , power and displacement. ​
#
# ​
#
# Cars produced in japan and europe are suitable of middle class people who need a more fuel efficient car .
